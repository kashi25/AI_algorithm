# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("test_dataset.csv")
df.head()
# Out:
#    Unnamed: 0    Id  MSSubClass  MSZoning  LotArea  Street  LotShape  \
# 0        1200  1202          60         3    10400       1         3
# 1        1201  1203          50         4     6000       1         3
# 2        1202  1204          20         3     9750       1         3
# 3        1203  1205          20         3    10140       1         3
# 4        1204  1206          20         3    14684       1         0
#
#    LandContour  Utilities  LotConfig  ...  EnclosedPorch  3SsnPorch  \
# 0            3          0          0  ...              0          0
# 1            3          0          0  ...            208          0
# 2            3          0          4  ...              0          0
# 3            3          0          4  ...              0          0
# 4            3          0          1  ...              0          0
#
#    ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# 0            0         0        0       3    2009         8              4
# 1            0         0        0       5    2009         8              4
# 2            0         0        0      10    2009         8              4
# 3            0         0        0       7    2006         8              4
# 4            0         0        0       6    2009         8              4
#
#    SalePrice
# 0  12.195517
# 1  11.669929
# 2  12.269047
# 3  11.941456
# 4  12.513190
#
# [5 rows x 72 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the data
df = pd.read_csv("test_dataset.csv")

# Create the scatter plot
plt.scatter(df['SalePrice'], df['Id'])
plt.xlabel('SalePrice')
plt.ylabel('id')
plt.title('Scatter plot of SalePrice vs id')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

df = pd.read_csv("test_dataset.csv")
df.head()
sns.scatterplot(x = 'SalePrice', y= 'Id', data =df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 3
#       1 import matplotlib.pyplot as plt
#       2 import pandas as pd
# ----> 3 import seaborn as sns
#       5 df = pd.read_csv("test_dataset.csv")
#       6 df.head()
#
# ModuleNotFoundError: No module named 'seaborn'
